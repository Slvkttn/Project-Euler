# %% [markdown]
# ### Problem Description

# %% [markdown]
# A number is a perfect square, or a square number, if it is the square of a positive integer.
#
# For example, 25 is a square number because `5² = 5 x 5 = 25`; it is also an odd square.
#
# The first 5 square numbers are: `1, 4, 9, 16, 25` and the sum of the odd squares is `1 + 9 + 25 = 35`
#
# Among the first **488 thousand** square numbers, what is the sum of all the odd squares?

# %%
def sum_odd_squares(num: int, verbose = False):
    
    sum_odds = 0

    if num < 0 or type(num) is not int:
        print(f"You inserted {num} which is a non-positive integer. Please insert a positive integer.")
        return sum_odds
    
    for number in range(1, num+1):

        if verbose == True:
            print(f"Now dealing with number: {number}")
        
        if number % 2 == 0:
            if verbose == True:
                print(f"Eww {number} is even! Skip that!")
            continue

        square_odd_num = number**2
        if verbose == True:
            print(f"So adding {square_odd_num} to {sum_odds}")
        
        sum_odds += square_odd_num
        if verbose == True:
            print(f"Gives me {square_odd_num}")

    return sum_odds

# %%
sum_odd_squares(5, True)
# Out:
# Now dealing with number: 1
# So adding 1 to 0
# Gives me 1
# Now dealing with number: 2
# Eww 2 is even! Skip that!
# Now dealing with number: 3
# So adding 9 to 1
# Gives me 9
# Now dealing with number: 4
# Eww 4 is even! Skip that!
# Now dealing with number: 5
# So adding 25 to 10
# Gives me 25
# 35

# %%
answer = sum_odd_squares(488000)

# %% [markdown]
# The answer to the question is...

# %%
answer
# Out:
# 19369045333252000
